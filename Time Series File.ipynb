# %%
import pandas as pd
df=pd.read_csv("starbucks.csv")

# %%
df.head()
# Out:
#          Date    Close    Volume
# 0  02-01-2015  38.0061   6906098
# 1  05-01-2015  37.2781  11623796
# 2  06-01-2015  36.9748   7664340
# 3  07-01-2015  37.8848   9732554
# 4  08-01-2015  38.4961  13170548

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006 entries, 0 to 1005
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1006 non-null   object
#  1   Close   1006 non-null   float64
#  2   Volume  1006 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 23.7+ KB

# %%
df=pd.read_csv("starbucks.csv",parse_dates=True,index_col='Date')
# Out:
# C:\Users\suraj\AppData\Local\Temp\ipykernel_16304\3425895915.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df=pd.read_csv("starbucks.csv",parse_dates=True,index_col='Date')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2015-02-01 to 2018-12-31
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1006 non-null   float64
#  1   Volume  1006 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 23.6 KB

# %%
df.drop('Volume',axis=1)
# Out:
#               Close
# Date
# 2015-02-01  38.0061
# 2015-05-01  37.2781
# 2015-06-01  36.9748
# 2015-07-01  37.8848
# 2015-08-01  38.4961
# ...             ...
# 2018-12-24  60.5600
# 2018-12-26  63.0800
# 2018-12-27  63.2000
# 2018-12-28  63.3900
# 2018-12-31  64.4000
#
# [1006 rows x 1 columns]

# %%
df=df.drop(columns='Volume')

# %%
df
# Out:
#               Close
# Date
# 2015-02-01  38.0061
# 2015-05-01  37.2781
# 2015-06-01  36.9748
# 2015-07-01  37.8848
# 2015-08-01  38.4961
# ...             ...
# 2018-12-24  60.5600
# 2018-12-26  63.0800
# 2018-12-27  63.2000
# 2018-12-28  63.3900
# 2018-12-31  64.4000
#
# [1006 rows x 1 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2015-02-01', '2015-05-01', '2015-06-01', '2015-07-01',
#                '2015-08-01', '2015-09-01', '2015-12-01', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df.Close.plot(figsize=(10,6));

# %%
df.loc['2015'].Close.plot(figsize=(10,6));

# %%
df['2015':'2017'].Close.plot(figsize=(10,6));
# Out:
# C:\Users\suraj\AppData\Local\Temp\ipykernel_16304\2189546419.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df['2015':'2017'].Close.plot(figsize=(10,6));

# %%
df['2015-01':'2015-08'].Close.plot(figsize=(10,6));
# Out:
# C:\Users\suraj\AppData\Local\Temp\ipykernel_16304\574740903.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df['2015-01':'2015-08'].Close.plot(figsize=(10,6));

# %%
df.loc['2015'].mean()
# Out:
# Close    50.0781
# dtype: float64

# %%
df.loc['2016'].mean()
# Out:
# Close    53.891732
# dtype: float64

# %%
df.loc['2017'].mean()
# Out:
# Close    55.45731
# dtype: float64

# %%
df['d1']=df.Close.diff()

# %%
df
# Out:
#               Close      d1
# Date
# 2015-02-01  38.0061     NaN
# 2015-05-01  37.2781 -0.7280
# 2015-06-01  36.9748 -0.3033
# 2015-07-01  37.8848  0.9100
# 2015-08-01  38.4961  0.6113
# ...             ...     ...
# 2018-12-24  60.5600 -0.8300
# 2018-12-26  63.0800  2.5200
# 2018-12-27  63.2000  0.1200
# 2018-12-28  63.3900  0.1900
# 2018-12-31  64.4000  1.0100
#
# [1006 rows x 2 columns]

# %%
df.d1.plot(figsize=(10,5));

# %%
(df.loc['2015'].d1.mean())
# Out:
# 0.0746820717131474

# %%
(df.loc['2016'].d1.mean())
# Out:
# -0.013802380952380957

# %%
df['dd1']=df.d1.diff()

# %%
df
# Out:
#               Close      d1     dd1
# Date
# 2015-02-01  38.0061     NaN     NaN
# 2015-05-01  37.2781 -0.7280     NaN
# 2015-06-01  36.9748 -0.3033  0.4247
# 2015-07-01  37.8848  0.9100  1.2133
# 2015-08-01  38.4961  0.6113 -0.2987
# ...             ...     ...     ...
# 2018-12-24  60.5600 -0.8300 -0.0700
# 2018-12-26  63.0800  2.5200  3.3500
# 2018-12-27  63.2000  0.1200 -2.4000
# 2018-12-28  63.3900  0.1900  0.0700
# 2018-12-31  64.4000  1.0100  0.8200
#
# [1006 rows x 3 columns]

# %%
round(df.loc['2015'].dd1.mean(),2)
# Out:
# -0.0

# %%
round(df.loc['2016'].dd1.mean(),2)
# Out:
# -0.0

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
 x=seasonal_decompose(df.Close)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 x=seasonal_decompose(df.Close)
#
# File ~\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py:159, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     157         period = pfreq
#     158     else:
# --> 159         raise ValueError(
#     160             "You must specify a period or x must be a pandas object with "
#     161             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     162         )
#     163 if x.shape[0] < 2 * pfreq:
#     164     raise ValueError(
#     165         f"x must have 2 complete cycles requires {2 * pfreq} "
#     166         f"observations. x only has {x.shape[0]} observation(s)"
#     167     )
#
# ...

# %%
df.index

# %%
df.index.freq='D'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py:1008, in DatetimeLikeArrayMixin._validate_frequency(cls, index, freq, **kwargs)
#    1007     if not np.array_equal(index.asi8, on_freq.asi8):
# -> 1008         raise ValueError
#    1009 except ValueError as e:
#
# ValueError:
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df.index.freq='D'
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\extension.py:81, in _inherit_from_data.<locals>.fset(self, value)
#      80 def fset(self, value):
# ---> 81     setattr(self._data, name, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py:937, in DatetimeLikeArrayMixin.freq(self, value)
# ...

# %%
df=df.asfreq('D')

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-04', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-10', '2015-01-11',
#                '2015-01-12', '2015-01-13',
#                ...
#                '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25',
#                '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-29',
#                '2018-12-30', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1458, freq='D')

# %%
df.head(10)
# Out:
#               Close      d1     dd1
# Date
# 2015-01-04  43.5687 -0.7869 -0.1874
# 2015-01-05  47.1097  0.6651  1.6674
# 2015-01-06  49.0733  0.2444  0.1035
# 2015-01-07  50.6426  0.2584  0.1973
# 2015-01-08      NaN     NaN     NaN
# 2015-01-09  50.4148 -1.1402 -0.2733
# 2015-01-10  54.1653  0.6031 -0.4523
# 2015-01-11      NaN     NaN     NaN
# 2015-01-12  58.0182 -0.0189  0.7279
# 2015-01-13  37.7401  0.2986  0.0932

# %%
x=seasonal_decompose(df.Close)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 x=seasonal_decompose(df.Close)
#
# File ~\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py:146, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     143 nobs = len(x)
#     145 if not np.all(np.isfinite(x)):
# --> 146     raise ValueError("This function does not handle missing values")
#     147 if model.startswith("m"):
#     148     if np.any(x <= 0):
#
# ValueError: This function does not handle missing values

# %%
df.Close.ffill(inplace=True)

# %%
df.head(15)
# Out:
#               Close      d1     dd1
# Date
# 2015-01-04  43.5687 -0.7869 -0.1874
# 2015-01-05  47.1097  0.6651  1.6674
# 2015-01-06  49.0733  0.2444  0.1035
# 2015-01-07  50.6426  0.2584  0.1973
# 2015-01-08  50.6426     NaN     NaN
# 2015-01-09  50.4148 -1.1402 -0.2733
# 2015-01-10  54.1653  0.6031 -0.4523
# 2015-01-11  54.1653     NaN     NaN
# 2015-01-12  58.0182 -0.0189  0.7279
# 2015-01-13  37.7401  0.2986  0.0932
# 2015-01-14  37.5301 -0.2100 -0.5086
# 2015-01-15  37.1381 -0.3920 -0.1820
# 2015-01-16  37.6188  0.4807  0.8727
# 2015-01-17  37.6188     NaN     NaN
# 2015-01-18  37.6188     NaN     NaN

# %%
x=seasonal_decompose(df.Close)

# %%
x.plot();

# %%
x.trend.plot();

# %%
x.seasonal.plot();

# %%
x.resid.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
x.trend.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
print('Dicky-Fuller Result')
result=adfuller(df['Close'])
result
# Out:
# Dicky-Fuller Result
# (-3.519113338589693,
#  0.007509578959683352,
#  24,
#  1433,
#  {'1%': -3.434921564946909,
#   '5%': -2.8635590328954197,
#   '10%': -2.567844919904611},
#  6608.608317793311)

# %%
dfout=pd.Series(result[0:4],index=['Adf test static','P-value','# lags used','#observation'])
dfout
# Out:
# Adf test static      -3.519113
# P-value               0.007510
# # lags used          24.000000
# #observation       1433.000000
# dtype: float64

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(series,title=''):
    print(f'Augmented Dickey-Fuller test: {title}')
    print()
    print('H0: Data has a  unit root and is non-stationary')
    print('Ha: Data has no unit root and is stationary')
    print('Reference P value:0.05')
    print()
    result=adfuller(series.dropna())
    index=['Adf test static','P-value','# lags used','#observations']
    
    out=pd.Series(result[0:4],index=index)
    
    if result[1]<=0.05:
        print('Strong evidence against the null hypothesis')
        print('Reject the null hypothesis')
        print('Data has no unit root and is stationary')
        
    else:
        print('Weak evidence against the null hypothesis')
        print('Accept the null hypothesis')
        print('Data has unit root and is non-stationary')

# %%
adf_test(df.Close,'Close Stationary check')
# Out:
# Augmented Dickey-Fuller test: Close Stationary check
#
# H0: Data has a  unit root and is non-stationary
# Ha: Data has no unit root and is stationary
# Reference P value:0.05
#
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
